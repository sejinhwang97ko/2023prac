# %% [markdown]
# ## 특정한 경로에 있는 파일의 목록 출력

# %%
import os #내제되어있음

# %%
file_list = os.listdir("../csv/csv/2017")

# %%
import pandas as pd

# %%
for i in range(1, 13, 1):
    a = "%02d"%i #두자리로 만들기 .2는 소수점
    file = '2017'+a+'_expense_list.csv'
    print(file)
# Out:
# 201701_expense_list.csv
# 201702_expense_list.csv
# 201703_expense_list.csv
# 201704_expense_list.csv
# 201705_expense_list.csv
# 201706_expense_list.csv
# 201707_expense_list.csv
# 201708_expense_list.csv
# 201709_expense_list.csv
# 201710_expense_list.csv
# 201711_expense_list.csv
# 201712_expense_list.csv

# %%
# read_csv()안에 들어가는 인자값을 생성
# 상대경로 : ../csv/csv/2017/파일명 -> 12개 출력
# 경로에 있는 파일들을 pandas를 이용하여 데이터프레임으로 불러온다.
# concat을 이용하여 단순하게 행을 추가하는 결합
# 결합을 하려면 기준이 되는 데이터프레임이 존재하여야한다.
# 비어있는 데이터프레임을 하나 생성

path = "../csv/csv/2017/"

file_list = os.listdir(path)

result = pd.DataFrame() # 빈 데이터프레임
for i in file_list:
    # print(path+i)
    df = pd.read_csv(path+i)
    result = pd.concat([result, df], axis = 0, ignore_index=True)

result.head(5)
# Out:
#         nid                         title  \
# 0  11430252  2017년 1월 장애인복지정책과 업무추진비 집행내역
# 1  11430252  2017년 1월 장애인복지정책과 업무추진비 집행내역
# 2  11430252  2017년 1월 장애인복지정책과 업무추진비 집행내역
# 3  11430252  2017년 1월 장애인복지정책과 업무추진비 집행내역
# 4  11430252  2017년 1월 장애인복지정책과 업무추진비 집행내역
#
#                                           url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0  http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 1  http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 2  http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 3  http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 4  http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
#
#   dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  \
# 0      장애인복지정책과           NaN           NaN     2017           1
# 1      장애인복지정책과           NaN           NaN     2017           1
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70132 entries, 0 to 70131
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                70132 non-null  int64
#  1   title              70132 non-null  object
#  2   url                70132 non-null  object
#  3   dept_nm_lvl_1      70132 non-null  object
#  4   dept_nm_lvl_2      70074 non-null  object
#  5   dept_nm_lvl_3      61262 non-null  object
#  6   dept_nm_lvl_4      17939 non-null  object
#  7   dept_nm_lvl_5      3474 non-null   object
#  8   exec_yr            70132 non-null  int64
#  9   exec_month         70132 non-null  int64
#  10  expense_budget     3108 non-null   float64
#  11  expense_execution  2805 non-null   float64
#  12  category           1259 non-null   object
#  13  dept_nm_full       70053 non-null  object
#  14  exec_dt            70132 non-null  object
#  15  exec_loc           69360 non-null  object
# ...

# %%
path = "../csv/csv/2019/"

file_list = os.listdir(path)
#file_list

result = pd.DataFrame() # 빈 데이터프레임
for i in file_list:
    # print(path+i)
    df = pd.read_json(path+i)
    result = pd.concat([result, df], axis = 0, ignore_index=True)

result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74207 entries, 0 to 74206
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                74207 non-null  int64
#  1   title              74207 non-null  object
#  2   url                74207 non-null  object
#  3   dept_nm_lvl_1      74207 non-null  object
#  4   dept_nm_lvl_2      74207 non-null  object
#  5   dept_nm_lvl_3      74207 non-null  object
#  6   dept_nm_lvl_4      74207 non-null  object
#  7   dept_nm_lvl_5      74207 non-null  object
#  8   exec_yr            74207 non-null  int64
#  9   exec_month         74207 non-null  int64
#  10  expense_budget     2075 non-null   float64
#  11  expense_execution  1598 non-null   float64
#  12  category           74028 non-null  object
#  13  dept_nm_full       74207 non-null  object
#  14  exec_dt            74207 non-null  object
#  15  exec_loc           74207 non-null  object
# ...

# %%
path = "../csv/csv/2020/"

file_list = os.listdir(path)
#file_list

result = pd.DataFrame() # 빈 데이터프레임
for i in file_list:
    # print(path+i)
    df = pd.read_excel(path+i)
    result = pd.concat([result, df], axis = 0, ignore_index=True)

result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70862 entries, 0 to 70861
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                70862 non-null  int64
#  1   title              70862 non-null  object
#  2   url                70862 non-null  object
#  3   dept_nm_lvl_1      70862 non-null  object
#  4   dept_nm_lvl_2      70862 non-null  object
#  5   dept_nm_lvl_3      55593 non-null  object
#  6   dept_nm_lvl_4      18992 non-null  object
#  7   dept_nm_lvl_5      1601 non-null   object
#  8   exec_yr            70862 non-null  int64
#  9   exec_month         70862 non-null  int64
#  10  expense_budget     1823 non-null   float64
#  11  expense_execution  1338 non-null   float64
#  12  category           2123 non-null   object
#  13  dept_nm_full       70862 non-null  object
#  14  exec_dt            70862 non-null  object
#  15  exec_loc           70278 non-null  object
# ...

# %%
file_list = os.listdir("../csv/csv/2022/")

file_list
# a = '.csv'
# b = '.json'
# c = '.xml'
# d = 
# for i in file_list:
#     if i.endswith(a): #마지막이 csv인지
#         print(i)
# Out:
# ['202202_expense_list.csv',
#  '202202_expense_list.json',
#  '202202_expense_list.xlsx',
#  '202202_expense_list.xml',
#  '202203_expense_list.csv',
#  '202203_expense_list.json',
#  '202203_expense_list.xlsx',
#  '202203_expense_list.xml',
#  '202204_expense_list.csv',
#  '202204_expense_list.json',
#  '202204_expense_list.xlsx',
#  '202204_expense_list.xml',
#  '202205_expense_list.csv',
#  '202205_expense_list.json',
#  '202205_expense_list.xlsx',
#  '202205_expense_list.xml']

# %%
def load(_dir, _end='.csv'):
    # _dir: 파일의 경로, _end: 파일의 확장자

    if ~(_dir.endswith("/")):
        _dir = _dir+"/"

    if _end[0] != ".":
        _end = "." + _end

    print (_dir, _end)

    # # 파일의 리스트 호출
    file_list = os.listdir(_dir)
    # print(file_list)

    # #비어있는 데이터프레임 생성
    result = pd.DataFrame()
    # # 파일 리스트에서 확장자가 같은 파일들만 결합
    for i in file_list:
        # 파일명의 확장자라는 인자값과 같은 경우
        if i.endswith(_end):
            # 확장자에 따른 read 함수 설정
            if _end == '.csv':
                df = pd.read_csv(_dir+i)
                result = pd.concat([result, df], axis = 0, ignore_index=True)
            elif _end == '.json':
                df = pd.read_json(_dir+i)
                result = pd.concat([result, df], axis = 0, ignore_index=True)
            elif _end in [".xlsx" , "xls"]: #(_end == '.xlsx' or _end == '.xls'): 
                df = pd.read_excel(_dir+i)
                result = pd.concat([result, df], axis = 0, ignore_index=True)
            else:
                return "지원하지 않는 확장자입니다."
    return result

# %%
list_load("../csv/csv/2021", ".xlsx")
# Out:
# ../csv/csv/2021/ .xlsx
#             nid                                              title  \
# 0      22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 1      22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 2      22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 3      22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 4      22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# ...         ...                                                ...
# 83814  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 83815  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 83816  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 83817  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 83818  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
#
#                                                url dept_nm_lvl_1  \
# 0       http://opengov.seoul.go.kr/public/22249566           사업소
# ...

# %% [markdown]
# list_load 폴더를 만들고
# __init__.py 파일 만들었는데
# 폴더가 실행될 때 먼저 실행되는 것.

# %%
import list_load as ll

# %%
ll.load("../csv/csv/2017")
# Out:
# ../csv/csv/2017/ .csv
#             nid                            title  \
# 0      11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 1      11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 2      11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 3      11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 4      11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# ...         ...                              ...
# 70127  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 70128  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 70129  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 70130  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 70131  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
#
#                                               url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0      http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 1      http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 2      http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# ...

# %% [markdown]
# ## 예제
# 1. csv 폴더에서 4개의 파일을 로드(tran_1, tran_2, tran_d_1, tran_d_2)
# 2. tran_1 과 tran_2는 단순한 행 추가 결합(유니언 결합)
# 3. tran_d_1과 tran_d_2도 유니언 결합
# 4. 2번, 3번 과정에서 나온 데이터프레임을 특정 조건에 맞춰서 2번 데이터프레임을 기준으로
# 열 추가 결합(조인 결합)
# 5. csv 폴더에 있는 2개의 파일 로드(custom_master, item_master)
# 6. 4번 과정에서 나온 데이터프레임과 custom_master 조인 결합(inner나 left를 제일 많이 씀)
# 7. 6번 과정에서 나온 데이터프레임과 item_master 조인 결합
# 8. 결합이 된 데이터프레임에서 quantity 컬럼과 item_price 컬럼의 데이터를 가지고 total_price라는 파생변수를 생성(total_price = item_price * quantity)

# %%
tran_1 = pd.read_csv("../csv/csv/tran_1.csv")
tran_2 = pd.read_csv("../csv/csv/tran_2.csv")
tran_d_1 = pd.read_csv("../csv/csv/tran_d_1.csv")
tran_d_2 = pd.read_csv("../csv/csv/tran_d_2.csv")

# %%
df1 = pd.concat([tran_1, tran_2], axis = 0, ignore_index=True)
df1
# Out:
#      transaction_id   price         payment_date customer_id
# 0       T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1       T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2       T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3       T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4       T0000000117  170000  2019-02-01 04:33:46    PL542865
# ...             ...     ...                  ...         ...
# 6781    T0000006894  180000  2019-07-31 21:20:44    HI400734
# 6782    T0000006895   85000  2019-07-31 21:52:48    AS339451
# 6783    T0000006896  100000  2019-07-31 23:35:25    OA027325
# 6784    T0000006897   85000  2019-07-31 23:39:35    TS624738
# 6785    T0000006898   85000  2019-07-31 23:41:38    AS834214
#
# [6786 rows x 4 columns]

# %%
df2 = pd.concat([tran_d_1, tran_d_2], axis = 0, ignore_index=True)
df2
# Out:
#       detail_id transaction_id item_id  quantity
# 0             0    T0000000113    S005         1
# 1             1    T0000000114    S001         1
# 2             2    T0000000115    S003         1
# 3             3    T0000000116    S005         1
# 4             4    T0000000117    S002         2
# ...         ...            ...     ...       ...
# 7139       7139    T0000006894    S004         1
# 7140       7140    T0000006895    S002         1
# 7141       7141    T0000006896    S001         2
# 7142       7142    T0000006897    S002         1
# 7143       7143    T0000006898    S002         1
#
# [7144 rows x 4 columns]

# %%
# 2번, 3번 과정에서 나온 데이터프레임을 특정 조건에 맞춰서 2번 데이터프레임을 기준으로 열 추가 결합(조인 결합)

df3 = pd.merge(df1, df2, on='transaction_id', how='left')
df3
# Out:
#      transaction_id   price         payment_date customer_id  detail_id  \
# 0       T0000000113  210000  2019-02-01 01:36:57    PL563502          0
# 1       T0000000114   50000  2019-02-01 01:37:23    HD678019          1
# 2       T0000000115  120000  2019-02-01 02:34:19    HD298120          2
# 3       T0000000116  210000  2019-02-01 02:47:23    IK452215          3
# 4       T0000000117  170000  2019-02-01 04:33:46    PL542865          4
# ...             ...     ...                  ...         ...        ...
# 7139    T0000006894  180000  2019-07-31 21:20:44    HI400734       7139
# 7140    T0000006895   85000  2019-07-31 21:52:48    AS339451       7140
# 7141    T0000006896  100000  2019-07-31 23:35:25    OA027325       7141
# 7142    T0000006897   85000  2019-07-31 23:39:35    TS624738       7142
# 7143    T0000006898   85000  2019-07-31 23:41:38    AS834214       7143
#
#      item_id  quantity
# 0       S005         1
# 1       S001         1
# 2       S003         1
# ...

# %%
# 5. csv 폴더에 있는 2개의 파일 로드(custom_master, item_master)

cus = pd.read_csv("../csv/csv/customer_master.csv")
item = pd.read_csv("../csv/csv/item_master.csv")

# %%
cus
# Out:
#      customer_id   name class gender           start_date end_date  \
# 0       OA832399   XXXX   C01      F  2015-05-01 00:00:00      NaN
# 1       PL270116  XXXXX   C01      M  2015-05-01 00:00:00      NaN
# 2       OA974876  XXXXX   C01      M  2015-05-01 00:00:00      NaN
# 3       HD024127  XXXXX   C01      F  2015-05-01 00:00:00      NaN
# 4       HD661448  XXXXX   C03      F  2015-05-01 00:00:00      NaN
# ...          ...    ...   ...    ...                  ...      ...
# 4187    HD676663   XXXX   C01      M  2019-03-14 00:00:00      NaN
# 4188    HD246549  XXXXX   C01      F  2019-03-14 00:00:00      NaN
# 4189    GD037007  XXXXX   C03      M  2019-03-14 00:00:00      NaN
# 4190    OA953150  XXXXX   C01      M  2019-03-14 00:00:00      NaN
# 4191    IK692635  XXXXX   C02      F  2019-03-15 00:00:00      NaN
#
#      campaign_id  is_deleted
# 0            CA1           0
# 1            CA1           0
# 2            CA1           0
# 3            CA1           0
# ...

# %%
df4 = pd.merge(df3, cus, on='customer_id', how='left')
df4
# Out:
#      transaction_id   price         payment_date customer_id  detail_id  \
# 0       T0000000113  210000  2019-02-01 01:36:57    PL563502          0
# 1       T0000000114   50000  2019-02-01 01:37:23    HD678019          1
# 2       T0000000115  120000  2019-02-01 02:34:19    HD298120          2
# 3       T0000000116  210000  2019-02-01 02:47:23    IK452215          3
# 4       T0000000117  170000  2019-02-01 04:33:46    PL542865          4
# ...             ...     ...                  ...         ...        ...
# 7139    T0000006894  180000  2019-07-31 21:20:44    HI400734       7139
# 7140    T0000006895   85000  2019-07-31 21:52:48    AS339451       7140
# 7141    T0000006896  100000  2019-07-31 23:35:25    OA027325       7141
# 7142    T0000006897   85000  2019-07-31 23:39:35    TS624738       7142
# 7143    T0000006898   85000  2019-07-31 23:41:38    AS834214       7143
#
#      item_id  quantity   name class gender           start_date  \
# ...

# %%
item
# Out:
#   item_id item_name  item_price
# 0    S001      PC-A       50000
# 1    S002      PC-B       85000
# 2    S003      PC-C      120000
# 3    S004      PC-D      180000
# 4    S005      PC-E      210000

# %%
df5 = pd.merge(df4, item, on='item_id', how='left')
df5
# Out:
#      transaction_id   price         payment_date customer_id  detail_id  \
# 0       T0000000113  210000  2019-02-01 01:36:57    PL563502          0
# 1       T0000000114   50000  2019-02-01 01:37:23    HD678019          1
# 2       T0000000115  120000  2019-02-01 02:34:19    HD298120          2
# 3       T0000000116  210000  2019-02-01 02:47:23    IK452215          3
# 4       T0000000117  170000  2019-02-01 04:33:46    PL542865          4
# ...             ...     ...                  ...         ...        ...
# 7139    T0000006894  180000  2019-07-31 21:20:44    HI400734       7139
# 7140    T0000006895   85000  2019-07-31 21:52:48    AS339451       7140
# 7141    T0000006896  100000  2019-07-31 23:35:25    OA027325       7141
# 7142    T0000006897   85000  2019-07-31 23:39:35    TS624738       7142
# 7143    T0000006898   85000  2019-07-31 23:41:38    AS834214       7143
#
#      item_id  quantity   name class gender           start_date  \
# ...

# %%
# 결합이 된 데이터프레임에서 quantity 컬럼과 item_price 컬럼의 데이터를 가지고
# total_price라는 파생변수를 생성(total_price = item_price * quantity)

df5['total_price'] = df5['item_price'] * df5['quantity']

# %%
df5
# Out:
#      transaction_id   price         payment_date customer_id  detail_id  \
# 0       T0000000113  210000  2019-02-01 01:36:57    PL563502          0
# 1       T0000000114   50000  2019-02-01 01:37:23    HD678019          1
# 2       T0000000115  120000  2019-02-01 02:34:19    HD298120          2
# 3       T0000000116  210000  2019-02-01 02:47:23    IK452215          3
# 4       T0000000117  170000  2019-02-01 04:33:46    PL542865          4
# ...             ...     ...                  ...         ...        ...
# 7139    T0000006894  180000  2019-07-31 21:20:44    HI400734       7139
# 7140    T0000006895   85000  2019-07-31 21:52:48    AS339451       7140
# 7141    T0000006896  100000  2019-07-31 23:35:25    OA027325       7141
# 7142    T0000006897   85000  2019-07-31 23:39:35    TS624738       7142
# 7143    T0000006898   85000  2019-07-31 23:41:38    AS834214       7143
#
#      item_id  quantity   name class gender           start_date  \
# ...

# %%
# payment_date를 시계열로 #2019-02-01 01:36:57
# item_name 기준으로 total 합계

df5['payment_date'] = pd.to_datetime(df5['payment_date']) #, format="%Y-%m-%d %H:%M:%S"

# %%
# pd.to_datetime(df5['payment_date'], format="%Y-%m-%d %H:%M:%S")
# Out:
# 0      2019-02-01 01:36:57
# 1      2019-02-01 01:37:23
# 2      2019-02-01 02:34:19
# 3      2019-02-01 02:47:23
# 4      2019-02-01 04:33:46
#                ...
# 7139   2019-07-31 21:20:44
# 7140   2019-07-31 21:52:48
# 7141   2019-07-31 23:35:25
# 7142   2019-07-31 23:39:35
# 7143   2019-07-31 23:41:38
# Name: payment_date, Length: 7144, dtype: datetime64[ns]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7144 entries, 0 to 7143
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  7144 non-null   object
#  1   price           7144 non-null   int64
#  2   payment_date    7144 non-null   datetime64[ns]
#  3   customer_id     7144 non-null   object
#  4   detail_id       7144 non-null   int64
#  5   item_id         7144 non-null   object
#  6   quantity        7144 non-null   int64
#  7   name            6069 non-null   object
#  8   class           6069 non-null   object
#  9   gender          6069 non-null   object
#  10  start_date      6069 non-null   object
#  11  end_date        1978 non-null   object
#  12  campaign_id     6069 non-null   object
#  13  is_deleted      6069 non-null   float64
#  14  item_name       7144 non-null   object
#  15  item_price      7144 non-null   int64
#  16  total_price     7144 non-null   int64
# ...

# %%
df6 = df5.groupby('item_name').sum()

# %%
df7 = df6.sort_values('total_price', ascending=False)
df7
# Out:
#                price  detail_id  quantity  is_deleted  item_price  total_price
# item_name
# PC-E       410010000    6498864      1822       496.0   375060000    382620000
# PC-D       176465000    2979806       900       238.0   154260000    162000000
# PC-A       181760000    7605911      3043       584.0   107150000    152150000
# PC-B       171205000    5137300      1785       387.0   121465000    151725000
# PC-C       135310000    3292915      1022       273.0   111480000    122640000

# %%
df7.index[0]
# Out:
# 'PC-E'

# %%
df5.isna().sum()
# Out:
# transaction_id       0
# price                0
# payment_date         0
# customer_id          0
# detail_id            0
# item_id              0
# quantity             0
# name              1075
# class             1075
# gender            1075
# start_date        1075
# end_date          5166
# campaign_id       1075
# is_deleted        1075
# item_name            0
# item_price           0
# total_price          0
# dtype: int64

# %%
df5['gender'].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
origin_data = df5.copy()

# %%
# loc를 이용하여 M-> 남자 로, F->여자 로 변경
df5.loc[df5['gender'] == 'M','gender'] = '남자'
df5.loc[df5['gender'] == 'F','gender'] = '여자'

# %%
df5.value_counts('gender')
# Out:
# gender
# 남자    3268
# 여자    2801
# dtype: int64

# %%
df5['gender'].unique()
# Out:
# array(['남자', '여자', nan], dtype=object)

# %%
origin_data['gender']
# Out:
# 0         M
# 1         M
# 2         F
# 3         M
# 4         M
#        ...
# 7139    NaN
# 7140      M
# 7141      F
# 7142    NaN
# 7143      M
# Name: gender, Length: 7144, dtype: object

# %%
def change(x):
    if x == 'F':
        result = "여자"
    elif x == 'M':
        result = "남자"
    else:
        result = "무응답"
    return result

origin_data['gender'].apply(change)
# Out:
# 0        남자
# 1        남자
# 2        여자
# 3        남자
# 4        남자
#        ...
# 7139    무응답
# 7140     남자
# 7141     여자
# 7142    무응답
# 7143     남자
# Name: gender, Length: 7144, dtype: object

# %%
origin_data['gender'].apply(lambda x: "남자" if (x == 'M') else ("여자" if (x == "F") else "무응답"))
# 앞이 참인 조건(x가 M이면 남자로), 다음은 거짓인 조건(x가 M이 아니면 여자) 
# x가 M이 아니고 F도 아니면 무응답
# Out:
# 0        남자
# 1        남자
# 2        여자
# 3        남자
# 4        남자
#        ...
# 7139    무응답
# 7140     남자
# 7141     여자
# 7142    무응답
# 7143     남자
# Name: gender, Length: 7144, dtype: object

# %%
# 시계열 데이터에서 월-년 추출해서 새로운 파생변수 payment_moth 생성
origin_data['payment_month'] = origin_data['payment_date'].dt.strftime('%m-%Y')

# %%
origin_data.head(1)
# Out:
#   transaction_id   price        payment_date customer_id  detail_id item_id  \
# 0    T0000000113  210000 2019-02-01 01:36:57    PL563502          0    S005
#
#    quantity name class gender           start_date end_date campaign_id  \
# 0         1   XX   C01      M  2018-07-01 00:00:00      NaN         CA1
#
#    is_deleted item_name  item_price  total_price payment_month
# 0         0.0      PC-E      210000       210000       02-2019

# %%
group_data = origin_data.groupby('payment_month').sum()

# %%
group_data['total_price'].plot() #선
# Out:
# <AxesSubplot:xlabel='payment_month'>

# %%
group_data['total_price'].plot.bar()
# Out:
# <AxesSubplot:xlabel='payment_month'>

# %%
pd.pivot_table(
    origin_data,
    index = 'payment_month',
    aggfunc= ['sum','mean', 'min'],
    values = 'total_price'
)
# Out:
#                       sum           mean         min
#               total_price    total_price total_price
# payment_month
# 02-2019         160185000  137615.979381       50000
# 03-2019         160370000  135791.701948       50000
# 04-2019         160510000  135565.878378       50000
# 05-2019         155420000  132837.606838       50000
# 06-2019         164030000  136464.226290       50000
# 07-2019         170620000  137264.682220       50000

# %%
origin_data.groupby('payment_month').agg(['mean','sum'])
# Out:
#                        price            detail_id           quantity        \
#                         mean        sum      mean      sum      mean   sum
# payment_month
# 02-2019        153943.298969  179190000     581.5   676866  1.205326  1403
# 03-2019        148497.036410  175375000    1754.0  2071474  1.208298  1427
# 04-2019        149256.756757  176720000    2936.5  3476816  1.200169  1421
# 05-2019        146482.905983  171385000    4113.5  4812795  1.188034  1390
# 06-2019        152574.875208  183395000    5299.5  6369999  1.202995  1446
# 07-2019        151798.069187  188685000    6522.0  8106846  1.194690  1485
#
#               is_deleted            item_price               total_price  \
#                     mean    sum           mean        sum           mean
# payment_month
# 02-2019         0.299497  298.0  122684.707904  142805000  137615.979381
# 03-2019         0.335657  337.0  121066.892464  142980000  135791.701948
# ...
