# %%
import matplotlib.pyplot as plt

# %%
# 선 그래프
x = [1,2,3,4]
y = [5,3,2,1]

plt.plot(x,y)
plt.show() #print 같은 느낌

# %%
x = [1,2,3,4]
y = [80, 70, 90, 60]

plt.bar(x,y)
plt.show()

# %%
x = [1,2,3,4]
y = [80, 70, 90, 60]

plt.barh(x,y) #눕히기
plt.show()

# %%
import numpy as np

# %%
x = np.random.rand(50) #0에서 1사이
y = np.random.rand(50)
color = np.random.rand(50) #랜덤하게 지정
area = (20 *np.random.rand(50))**2 #숫자 키우는 작업

plt.scatter(x,y, s = area, c = color,alpha=0.6 )# s는 크기 #c는 컬러, 알파는 투명도
plt.show()

# %%
import seaborn as sns

# %%
import pandas as pd
drinks = pd.read_csv('../csv/csv/drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
corr = drinks[
    [
        'beer_servings',
        'spirit_servings',
        'wine_servings',
        'total_litres_of_pure_alcohol'
    ]
    ].corr(method='pearson')

corr
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
# 히트맵 출력
cols_view = ['beer', 'spirit', 'wine', 'alcohol']

sns.set(font_scale=1.5) #글자크기 늘려주기

hm = sns.heatmap(
    corr.values,
    cbar= True,
    annot = True, # 히트맵에 숫자 표시
    square = True, # 정사각형
    fmt = '.2f',
    annot_kws= {'size': 20}, #글자 크기
    xticklabels= cols_view, #x축 이름
    yticklabels = cols_view
)

plt.tight_layout()
plt.show()

# %%
# 히트맵 출력
cols_view = ['beer', 'spirit', 'wine', 'alcohol']

sns.set(font_scale=1.5) #글자크기 늘려주기

hm = sns.heatmap(
    corr.values,
    cbar= True,
    annot = True, # 히트맵에 숫자 표시
    square = False, 
    fmt = '.2f',
    annot_kws= {'size': 20},
    xticklabels= cols_view,
    yticklabels = cols_view
)

plt.tight_layout()
plt.show()

# %%
sns.set(style='whitegrid', context='notebook')

sns.pairplot(
    drinks[
    [
        'beer_servings',
        'spirit_servings',
        'wine_servings',
        'total_litres_of_pure_alcohol'
    ]
    ],
    height =2.5
)
