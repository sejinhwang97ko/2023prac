# %%
import pandas as pd
import momentum as mn
import imp
imp.reload(mn)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4704\2926693973.py in <module>
#       2 import momentum as mn
#       3 import imp
# ----> 4 imp.reload(mn)
#
# c:\Python 3.7.1\lib\imp.py in reload(module)
#     312
#     313     """
# --> 314     return importlib.reload(module)
#     315
#     316
#
# c:\Python 3.7.1\lib\importlib\__init__.py in reload(module)
#     166         spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#     167         if spec is None:
# --> 168             raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
#     169         _bootstrap._exec(spec, module)
#     170         # The module may have replaced itself in sys.modules!
#
# ModuleNotFoundError: spec not found for the module 'momentum'

# %%
df = pd.read_csv("../csv/csv/AAPL.csv")

# %%
df1 = mn.func_1(df,'Close')
df1.head()
# Out:
#                 Close   STD-YM
# Date
# 2010-01-04  30.572857  2010-01
# 2010-01-05  30.625713  2010-01
# 2010-01-06  30.138571  2010-01
# 2010-01-07  30.082857  2010-01
# 2010-01-08  30.282858  2010-01

# %%
df2 = mn.func_2(df1)
df2.iloc[8:15]
# Out:
# c:\Users\Sejin\Documents\GitHub\2023prac\20230417\momentum.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['BF_1M'] = df2[col].shift(1)
# c:\Python 3.7.1\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# c:\Users\Sejin\Documents\GitHub\2023prac\20230417\momentum.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
mn.func_3(df1,df2)
# Out:
# c:\Users\Sejin\Documents\GitHub\2023prac\20230417\momentum.py:57: RuntimeWarning: invalid value encountered in double_scalars
#   momentum_index = df2.loc[i,'BF_1M']/df2.loc[i,'BF_12M'] -1
# c:\Users\Sejin\Documents\GitHub\2023prac\20230417\momentum.py:57: RuntimeWarning: divide by zero encountered in double_scalars
#   momentum_index = df2.loc[i,'BF_1M']/df2.loc[i,'BF_12M'] -1
# 진입일:  2011-01-31 00:00:00 진입가격:  48.474285
# 판매일:  2011-02-01 00:00:00 판매가격:  49.290001 수익율:  1.0168278088062566
# 진입일:  2011-02-28 00:00:00 진입가격:  50.458572
# 판매일:  2011-03-01 00:00:00 판매가격:  49.901428 수익율:  0.9889583874866694
# 진입일:  2011-03-31 00:00:00 진입가격:  49.787144
# 판매일:  2011-04-01 00:00:00 판매가격:  49.222858 수익율:  0.9886660299293328
# 진입일:  2011-04-29 00:00:00 진입가격:  50.01857
# 판매일:  2011-05-02 00:00:00 판매가격:  49.468571 수익율:  0.9890041038758205
# 진입일:  2011-05-31 00:00:00 진입가격:  49.689999
# 판매일:  2011-06-01 00:00:00 판매가격:  49.35857 수익율:  0.993330066277522
# 진입일:  2011-06-30 00:00:00 진입가격:  47.952858
# ...

# %%
import invest
import imp
imp.reload(invest)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4704\1849231794.py in <module>
#       1 import invest
#       2 import imp
# ----> 3 imp.reload(invest)
#
# c:\Python 3.7.1\lib\imp.py in reload(module)
#     312
#     313     """
# --> 314     return importlib.reload(module)
#     315
#     316
#
# c:\Python 3.7.1\lib\importlib\__init__.py in reload(module)
#     167         if spec is None:
#     168             raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 169         _bootstrap._exec(spec, module)
#     170         # The module may have replaced itself in sys.modules!
#     171         return sys.modules[name]
#
# c:\Python 3.7.1\lib\importlib\_bootstrap.py in _exec(spec, module)
#
# c:\Python 3.7.1\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ...

# %%
test = invest.Invest(df,'Close')

# %%
test.momentum()
# Out:
# c:\Users\Sejin\Documents\GitHub\2023prac\20230417\momentum.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['BF_1M'] = df2[col].shift(1)
# c:\Python 3.7.1\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# c:\Users\Sejin\Documents\GitHub\2023prac\20230417\momentum.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
test.buyandhold
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4704\3204170857.py in <module>
# ----> 1 test.buyandhold
#
# AttributeError: 'Invest' object has no attribute 'buyandhold'
