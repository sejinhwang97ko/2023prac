# %%
import pandas as pd

# %%
pd.read_csv("../corona.csv")
# Out:
#       Unnamed: 0                 createDt  deathCnt  decideCnt   seq  \
# 0              0    2023-04-07 00:16:52.0     34318   30894559  1218
# 1              1    2023-04-05 02:12:00.0     34296   30871740  1216
# 2              2    2023-04-04 05:10:20.0     34289   30857275  1215
# 3              3    2023-04-03 00:00:13.0     34281   30843900  1214
# 4              4    2023-04-02 22:59:44.0     34274   30839551  1213
# ...          ...                      ...       ...        ...   ...
# 1157        1157  2020-01-24 00:00:00.000         0          2     5
# 1158        1158  2020-01-23 09:00:00.000         0          1     4
# 1159        1159  2020-01-22 12:00:00.000         0          1     3
# 1160        1160  2020-01-21 09:00:00.000         0          1     2
# 1161        1161  2020-01-20 17:00:00.000         0          1     1
#
#        stateDt stateTime                updateDt  accExamCnt  accDefRate
# ...
