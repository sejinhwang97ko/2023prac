# %%
import requests
import xmltodict
import pandas as pd
from urllib import parse

# %%
# !pip install xmltodict

# %% [markdown]
# 공공데이터포털 - 활용신청한 후 상세설명
#
# 상세기능 - 요청주소
#
# 요청변수 - 적어야할 인자값
# 옵션은 기본값이 설정되어있지 않은 매개변수
#
# 출력결과 - 전체 결과 수까지는 필요없음.
#
# 샘플코드 - 파이썬 샘플코드

# %%
# Python3 샘플 코드 #서비스 정보에서 디코딩 일반 인증키만 추가로 가져와서 붙이기

url = 'http://apis.data.go.kr/1160100/service/GetFnCoBasiInfoService/getFnCoOutl'
params ={'serviceKey' : 'FiwqPf2MmdO0PtX4ZcVCyPq64paXOWum8unJQzYyGpHIHz6jvry6UF2pG2MskbQ8MQ8i6FwnMBhj+TLvchgssA==',
 'pageNo' : '1', 'numOfRows' : '10',
 'resultType' : 'xml', 'basDt' : '20200408', 'crno' : '1101113892240', 'fncoNm' : '메리츠자산운용' }

response = requests.get(url, params=params)
print(response.content)

# 파이썬 샘플코드
# import requests

# url = 'http://apis.data.go.kr/1160100/service/GetFnCoBasiInfoService/getFnCoOutl'
# params ={'serviceKey' : '서비스키',
#  'pageNo' : '1', 'numOfRows' : '10',
#  'resultType' : 'xml', 'basDt' : '20200408', 'crno' : '1101113892240', 'fncoNm' : '메리츠자산운용' }

# response = requests.get(url, params=params)
# print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<response>\n    <header>\n        <resultCode>00</resultCode>\n        <resultMsg>NORMAL SERVICE.</resultMsg>\n    </header>\n    <body>\n        <numOfRows>10</numOfRows>\n        <pageNo>1</pageNo>\n        <totalCount>1</totalCount>\n        <items>\n            <item>\n                <actnAudpnNm></actnAudpnNm>\n                <audtRptOpnnCtt></audtRptOpnnCtt>\n                <basDt>20200408</basDt>\n                <bzno>1078708658</bzno>\n                <corpRegMrktDcd>E</corpRegMrktDcd>\n                <corpRegMrktDcdNm>\xea\xb8\xb0\xed\x83\x80</corpRegMrktDcdNm>\n                <crno>1101113892240</crno>\n                <empeAvgCnwkTermCtt></empeAvgCnwkTermCtt>\n                <fncoAdr>\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xec\xa2\x85\xeb\xa1\x9c\xea\xb5\xac \xeb\xb6\x81\xec\xb4\x8c\xeb\xa1\x9c 104 \xea\xb3\x84\xeb\x8f\x99\xeb\xb9\x8c\xeb\x94\xa9</fncoAdr>\n                <fncoEmpeAvgS
# ...

# %%
#xml 데이터를 dict 형태의 데이터로 변환
data = xmltodict.parse(response.content)
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'numOfRows': '10',
#    'pageNo': '1',
#    'totalCount': '1',
#    'items': {'item': {'actnAudpnNm': None,
#      'audtRptOpnnCtt': None,
#      'basDt': '20200408',
#      'bzno': '1078708658',
#      'corpRegMrktDcd': 'E',
#      'corpRegMrktDcdNm': '기타',
#      'crno': '1101113892240',
#      'empeAvgCnwkTermCtt': None,
#      'fncoAdr': '서울특별시 종로구 북촌로 104 계동빌딩',
#      'fncoEmpeAvgSlryAmt': '0',
#      'fncoEmpeCnt': '0',
#      'fncoEnsnNm': 'Meritz Asset Management',
#      'fncoEstbDt': '20080506',
#      'fncoFxno': '02-6320-3009',
#      'fncoHmpgUrl': None,
#      'fncoKosdaqLstgAbolDt': None,
#      'fncoKosdaqLstgDt': None,
#      'fncoKrxLstgAbolDt': None,
#      'fncoKrxLstgDt': None,
#      'fncoMainBizNm': None,
#      'fncoNm': '메리츠자산운용',
#      'fncoRprNm': 'John Lee(이정복)',
#      'fncoSmenpYn': None,
#      'fncoStacMm': '12',
#      'fncoTlno': '02-6320-3000',
# ...

# %%
#xml 데이터를 dict 형태의 데이터로 변환
xmltodict.parse(response.content)['response']['body']['items']['item'] #불필요한 {}를 빼줬다.
# Out:
# {'actnAudpnNm': None,
#  'audtRptOpnnCtt': None,
#  'basDt': '20200408',
#  'bzno': '1078708658',
#  'corpRegMrktDcd': 'E',
#  'corpRegMrktDcdNm': '기타',
#  'crno': '1101113892240',
#  'empeAvgCnwkTermCtt': None,
#  'fncoAdr': '서울특별시 종로구 북촌로 104 계동빌딩',
#  'fncoEmpeAvgSlryAmt': '0',
#  'fncoEmpeCnt': '0',
#  'fncoEnsnNm': 'Meritz Asset Management',
#  'fncoEstbDt': '20080506',
#  'fncoFxno': '02-6320-3009',
#  'fncoHmpgUrl': None,
#  'fncoKosdaqLstgAbolDt': None,
#  'fncoKosdaqLstgDt': None,
#  'fncoKrxLstgAbolDt': None,
#  'fncoKrxLstgDt': None,
#  'fncoMainBizNm': None,
#  'fncoNm': '메리츠자산운용',
#  'fncoRprNm': 'John Lee(이정복)',
#  'fncoSmenpYn': None,
#  'fncoStacMm': '12',
#  'fncoTlno': '02-6320-3000',
#  'fncoXchgLstgAbolDt': None,
#  'fncoXchgLstgDt': None,
#  'fncoZpcd': '03051',
#  'fssCorpChgDtm': '2020/03/23',
#  'fssCorpUnqNo': '00685935',
#  'isinCd': None,
#  'isinCdNm': None,
#  'mntrFcnFncoCd': None,
#  'mntrFcnFncoCdNm': None,
#  'sicCd': None,
#  'sicNm': '64201'}

# %%
dict_data = data['response']['body']['items']['item']
dict_data
# Out:
# {'actnAudpnNm': None,
#  'audtRptOpnnCtt': None,
#  'basDt': '20200408',
#  'bzno': '1078708658',
#  'corpRegMrktDcd': 'E',
#  'corpRegMrktDcdNm': '기타',
#  'crno': '1101113892240',
#  'empeAvgCnwkTermCtt': None,
#  'fncoAdr': '서울특별시 종로구 북촌로 104 계동빌딩',
#  'fncoEmpeAvgSlryAmt': '0',
#  'fncoEmpeCnt': '0',
#  'fncoEnsnNm': 'Meritz Asset Management',
#  'fncoEstbDt': '20080506',
#  'fncoFxno': '02-6320-3009',
#  'fncoHmpgUrl': None,
#  'fncoKosdaqLstgAbolDt': None,
#  'fncoKosdaqLstgDt': None,
#  'fncoKrxLstgAbolDt': None,
#  'fncoKrxLstgDt': None,
#  'fncoMainBizNm': None,
#  'fncoNm': '메리츠자산운용',
#  'fncoRprNm': 'John Lee(이정복)',
#  'fncoSmenpYn': None,
#  'fncoStacMm': '12',
#  'fncoTlno': '02-6320-3000',
#  'fncoXchgLstgAbolDt': None,
#  'fncoXchgLstgDt': None,
#  'fncoZpcd': '03051',
#  'fssCorpChgDtm': '2020/03/23',
#  'fssCorpUnqNo': '00685935',
#  'isinCd': None,
#  'isinCdNm': None,
#  'mntrFcnFncoCd': None,
#  'mntrFcnFncoCdNm': None,
#  'sicCd': None,
#  'sicNm': '64201'}

# %%
pd.DataFrame(dict_data.values(), index =dict_data.keys())
# Out:
#                                             0
# actnAudpnNm                              None
# audtRptOpnnCtt                           None
# basDt                                20200408
# bzno                               1078708658
# corpRegMrktDcd                              E
# corpRegMrktDcdNm                           기타
# crno                            1101113892240
# empeAvgCnwkTermCtt                       None
# fncoAdr                서울특별시 종로구 북촌로 104 계동빌딩
# fncoEmpeAvgSlryAmt                          0
# fncoEmpeCnt                                 0
# fncoEnsnNm            Meritz Asset Management
# fncoEstbDt                           20080506
# fncoFxno                         02-6320-3009
# fncoHmpgUrl                              None
# fncoKosdaqLstgAbolDt                     None
# fncoKosdaqLstgDt                         None
# fncoKrxLstgAbolDt                        None
# fncoKrxLstgDt                            None
# ...
